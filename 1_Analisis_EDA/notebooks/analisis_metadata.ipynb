# %%
"""
OBJETIVO DEL NOTEBOOK (METADATA)

Este notebook realiza Análisis Exploratorio de Datos (EDA)
sobre el dataset:

- metadata.json

Ubicación:
../data/raw/Electronics/Electronics.json

------------------------------------------------------------
FASES DEL ANÁLISIS
------------------------------------------------------------

1. Exploración inicial:
   - Columnas disponibles
   - Tipos de datos
   - Número de registros
   - Valores nulos

2. Evaluación de calidad:
   - Columnas irrelevantes
   - Inconsistencias
   - Datos faltantes

3. Definición de reglas:
   - Qué columnas eliminar
   - Qué columnas mantener
   - Limpieza de strings
   - Estandarización de nombres

------------------------------------------------------------
IMPORTANTE
------------------------------------------------------------

- Este notebook es SOLO para análisis (EDA)
- NO guardar datasets finales aquí
- NO hacer procesamiento masivo
- NO aplicar chunks aquí

El procesamiento real se realiza en:
src/etl_metadata.py

------------------------------------------------------------
SALIDA ESPERADA
------------------------------------------------------------

Lista clara de:
✔ columnas a usar
✔ columnas a eliminar
✔ reglas de limpieza
"""
