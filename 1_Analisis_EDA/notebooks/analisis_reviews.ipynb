# %%
"""
OBJETIVO DEL NOTEBOOK (REVIEWS)

Este notebook realiza Análisis Exploratorio de Datos (EDA)
sobre el dataset:

- reviews.json

Ubicación:
../data/raw/Reviews/meta_Electronics.json

------------------------------------------------------------
FASES DEL ANÁLISIS
------------------------------------------------------------

1. Exploración inicial:
   - Columnas disponibles
   - Tipos de datos
   - Número de registros
   - Valores nulos

2. Evaluación de calidad:
   - Columnas irrelevantes
   - Datos incompletos
   - Problemas en fechas

3. Definición de reglas:
   - Eliminación de columnas pesadas 
   - Normalización de fechas
   - Manejo de nulos
   - Selección de columnas clave

------------------------------------------------------------
IMPORTANTE
------------------------------------------------------------

- Este notebook es SOLO para análisis (EDA)
- NO usar para procesamiento de millones de filas
- NO usar chunks aquí
- NO exportar datasets finales

El ETL real se ejecuta en:
src/etl_reviews.py

------------------------------------------------------------
SALIDA ESPERADA
------------------------------------------------------------

✔ columnas a usar
✔ reglas de limpieza
✔ estructura para ETL
"""
